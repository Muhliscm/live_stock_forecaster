# %%
#pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# %%
msft = yf.Ticker("AAPL")

# %%
msft.info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 100000,
# ...

# %%
hist = msft.history(period="max", interval ="1d")

# %%
hist
# Out:
#                   Open        High         Low       Close      Volume  \
# Date
# 1986-03-13    0.055898    0.064119    0.055898    0.061378  1031788800
# 1986-03-14    0.061378    0.064667    0.061378    0.063570   308160000
# 1986-03-17    0.063570    0.065215    0.063570    0.064667   133171200
# 1986-03-18    0.064667    0.065215    0.062474    0.063022    67766400
# 1986-03-19    0.063022    0.063570    0.061378    0.061926    47894400
# ...                ...         ...         ...         ...         ...
# 2022-01-31  308.950012  312.380005  306.369995  310.980011    46444500
# 2022-02-01  310.410004  310.630005  305.130005  308.760010    40950400
# 2022-02-02  309.630005  315.119995  308.880005  313.459991    36636000
# 2022-02-03  309.489990  311.230011  299.959991  301.250000    43730000
# 2022-02-04  300.209991  308.799988  299.970001  305.940002    35070300
#
#             Dividends  Stock Splits
# Date
# 1986-03-13        0.0           0.0
# ...

# %%
msft.financials
# Out:
#                                             2021-06-30      2020-06-30  \
# Research Development                     20716000000.0   19269000000.0
# Effect Of Accounting Charges                      None            None
# Income Before Tax                        71102000000.0   53036000000.0
# Minority Interest                                 None            None
# Net Income                               61271000000.0   44281000000.0
# Selling General Administrative           25224000000.0   24523000000.0
# Gross Profit                            115856000000.0   96937000000.0
# Ebit                                     69916000000.0   53145000000.0
# Operating Income                         69916000000.0   53145000000.0
# Other Operating Expenses                          None            None
# Interest Expense                         -2330000000.0   -2591000000.0
# Extraordinary Items                               None            None
# ...

# %%
len(close)
# Out:
# 9050

# %%
close
# Out:
# Date
# 1986-03-13      0.061378
# 1986-03-14      0.063570
# 1986-03-17      0.064667
# 1986-03-18      0.063022
# 1986-03-19      0.061926
#                  ...
# 2022-01-31    310.980011
# 2022-02-01    308.760010
# 2022-02-02    313.459991
# 2022-02-03    301.250000
# 2022-02-04    305.940002
# Name: Close, Length: 9050, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(close)

# %%
df.shape
# Out:
# (9050, 7)

# %%
df = msft.history(period="max", interval="1d")

# %%
df
# Out:
#                   Open        High         Low       Close      Volume  \
# Date
# 1986-03-13    0.055898    0.064119    0.055898    0.061378  1031788800
# 1986-03-14    0.061378    0.064667    0.061378    0.063570   308160000
# 1986-03-17    0.063570    0.065215    0.063570    0.064667   133171200
# 1986-03-18    0.064667    0.065215    0.062474    0.063022    67766400
# 1986-03-19    0.063022    0.063570    0.061378    0.061926    47894400
# ...                ...         ...         ...         ...         ...
# 2022-01-31  308.950012  312.380005  306.369995  310.980011    46444500
# 2022-02-01  310.410004  310.630005  305.130005  308.760010    40950400
# 2022-02-02  309.630005  315.119995  308.880005  313.459991    36636000
# 2022-02-03  309.489990  311.230011  299.959991  301.250000    43730000
# 2022-02-04  300.209991  308.799988  299.970001  305.940002    35070300
#
#             Dividends  Stock Splits
# Date
# 1986-03-13        0.0           0.0
# ...

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x=df.index,
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])
fig.show()

# %%
month_data["Close"]
# Out:
# Series([], Name: Close, dtype: float64)

# %%
month_data.index
# Out:
# Index([], dtype='object', name='Date')

# %%
ytd_data = msft.history(period = "ytd")

# %%
ytd_data.shape
# Out:
# (21, 7)

# %%
plt.figure(figsize = (20, 20))
plt.plot(ytd_data["Close"])

# %%
ytd_data_hr = msft.history(period = "ytd", interval="1h")

# %%
ytd_data_hr.shape
# Out:
# (142, 7)

# %%
ytd_data
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2022-01-03  335.350006  338.000000  329.779999  334.750000  28865100
# 2022-01-04  334.829987  335.200012  326.119995  329.010010  32674300
# 2022-01-05  325.859985  326.070007  315.980011  316.380005  40054300
# 2022-01-06  313.149994  318.700012  311.489990  313.880005  39646100
# 2022-01-07  314.149994  316.500000  310.089996  314.040009  32674000
# 2022-01-10  309.489990  314.720001  304.690002  314.269989  44289500
# 2022-01-11  313.380005  316.609985  309.890015  314.980011  29386800
# 2022-01-12  319.670013  323.410004  317.079987  318.269989  34372200
# 2022-01-13  320.470001  320.880005  304.000000  304.799988  45366000
# 2022-01-14  304.250000  310.820007  303.750000  310.200012  39823500
# 2022-01-18  304.070007  309.799988  301.739990  302.649994  42333200
# 2022-01-19  306.290009  313.910004  302.700012  303.329987  45933900
# ...

# %%
plt.plot(ytd_data_hr["Close"])
